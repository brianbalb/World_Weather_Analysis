# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# import the requests library
import requests

# import the API key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# starting url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create a set of 2000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Get the nearest city using citipy
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Perfom API call using OpenWeatherMap

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If error, skip the city.
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cockburn town
# Processing Record 2 of Set 1 | outram
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | kalispell
# Processing Record 5 of Set 1 | juneau
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | boa vista
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | dingle
# Processing Record 11 of Set 1 | mahibadhoo
# Processing Record 12 of Set 1 | tartagal
# Processing Record 13 of Set 1 | baoning
# Processing Record 14 of Set 1 | cacule
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | vestmannaeyjar
# Processing Record 18 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | cimitarra
# Processing Record 21 of Set 1 | balabac
# Processing Record 22 of Set 1 | guerrero negro
# Processing Record 23 of Set 1 | oslo
# Processing Record 24 of Set 1 | krasnoborsk
# Processing Record 25 of Set 1 | erenhot
# Processing Record 26 of Set 1 | gulshat
# City not found. Skipping...
# Processing Record 27 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 1 | acapulco
# Processing Record 29 of Set 1 | manono
# Processing Record 30 of Set 1 | husavik
# Processing Record 31 of Set 1 | airai
# Processing Record 32 of Set 1 | buchanan
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | bhakkar
# Processing Record 35 of Set 1 | marzuq
# Processing Record 36 of Set 1 | tillabery
# City not found. Skipping...
# Processing Record 37 of Set 1 | felipe carrillo puerto
# Processing Record 38 of Set 1 | mozarlandia
# Processing Record 39 of Set 1 | ornskoldsvik
# Processing Record 40 of Set 1 | richards bay
# Processing Record 41 of Set 1 | nome
# Processing Record 42 of Set 1 | tuatapere
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | norman wells
# Processing Record 45 of Set 1 | pitimbu
# Processing Record 46 of Set 1 | grindavik
# Processing Record 47 of Set 1 | panalingaan
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | kalangala
# Processing Record 2 of Set 2 | eureka
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | dashitou
# Processing Record 5 of Set 2 | camacupa
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 2 | talnakh
# Processing Record 9 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 2 | biak
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | talara
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | mildura
# Processing Record 17 of Set 2 | elizabeth city
# Processing Record 18 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 2 | yima
# Processing Record 20 of Set 2 | sao joao da barra
# Processing Record 21 of Set 2 | mar del plata
# Processing Record 22 of Set 2 | la ronge
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | pevek
# Processing Record 25 of Set 2 | kloulklubed
# Processing Record 26 of Set 2 | birzai
# Processing Record 27 of Set 2 | alofi
# Processing Record 28 of Set 2 | luderitz
# Processing Record 29 of Set 2 | jinchang
# Processing Record 30 of Set 2 | shaunavon
# Processing Record 31 of Set 2 | vaini
# Processing Record 32 of Set 2 | mahebourg
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | san patricio
# Processing Record 35 of Set 2 | zajecar
# Processing Record 36 of Set 2 | albany
# Processing Record 37 of Set 2 | comodoro rivadavia
# Processing Record 38 of Set 2 | ilulissat
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | ballina
# Processing Record 43 of Set 2 | kavaratti
# Processing Record 44 of Set 2 | toyooka
# Processing Record 45 of Set 2 | cherskiy
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | diego de almagro
# Processing Record 48 of Set 2 | cayenne
# Processing Record 49 of Set 2 | cidreira
# Processing Record 50 of Set 2 | hambantota
# Processing Record 1 of Set 3 | isangel
# Processing Record 2 of Set 3 | nova odesa
# Processing Record 3 of Set 3 | zyryanka
# Processing Record 4 of Set 3 | innisfail
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 3 | drayton valley
# Processing Record 8 of Set 3 | karasuk
# Processing Record 9 of Set 3 | nouakchott
# Processing Record 10 of Set 3 | sabang
# Processing Record 11 of Set 3 | kavieng
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | sao jose da coroa grande
# Processing Record 15 of Set 3 | tampakan
# Processing Record 16 of Set 3 | chapais
# Processing Record 17 of Set 3 | aparecida do taboado
# Processing Record 18 of Set 3 | tandil
# Processing Record 19 of Set 3 | halden
# Processing Record 20 of Set 3 | saldanha
# Processing Record 21 of Set 3 | ratnagiri
# Processing Record 22 of Set 3 | olavarria
# Processing Record 23 of Set 3 | te anau
# Processing Record 24 of Set 3 | russell
# Processing Record 25 of Set 3 | longyearbyen
# Processing Record 26 of Set 3 | vao
# Processing Record 27 of Set 3 | ancud
# Processing Record 28 of Set 3 | rabaul
# Processing Record 29 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 30 of Set 3 | fortuna
# Processing Record 31 of Set 3 | suwannaphum
# Processing Record 32 of Set 3 | svetlyy
# Processing Record 33 of Set 3 | saquarema
# Processing Record 34 of Set 3 | brora
# Processing Record 35 of Set 3 | villa rica
# Processing Record 36 of Set 3 | dhidhdhoo
# Processing Record 37 of Set 3 | qaanaaq
# Processing Record 38 of Set 3 | zaliztsi
# Processing Record 39 of Set 3 | sao filipe
# Processing Record 40 of Set 3 | los llanos de aridane
# Processing Record 41 of Set 3 | castro
# Processing Record 42 of Set 3 | kirakira
# Processing Record 43 of Set 3 | lubango
# Processing Record 44 of Set 3 | nocera superiore
# Processing Record 45 of Set 3 | flinders
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | jalingo
# Processing Record 48 of Set 3 | haines junction
# Processing Record 49 of Set 3 | clyde river
# Processing Record 50 of Set 3 | mbour
# Processing Record 1 of Set 4 | naze
# Processing Record 2 of Set 4 | maceio
# Processing Record 3 of Set 4 | smithers
# Processing Record 4 of Set 4 | ati
# Processing Record 5 of Set 4 | leningradskiy
# Processing Record 6 of Set 4 | gotsu
# Processing Record 7 of Set 4 | yellowknife
# Processing Record 8 of Set 4 | taoudenni
# Processing Record 9 of Set 4 | la asuncion
# Processing Record 10 of Set 4 | codrington
# Processing Record 11 of Set 4 | srednekolymsk
# Processing Record 12 of Set 4 | provideniya
# Processing Record 13 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 4 | karratha
# Processing Record 15 of Set 4 | qingdao
# Processing Record 16 of Set 4 | qinzhou
# Processing Record 17 of Set 4 | filadelfia
# Processing Record 18 of Set 4 | suntar
# Processing Record 19 of Set 4 | talcahuano
# Processing Record 20 of Set 4 | veshenskaya
# Processing Record 21 of Set 4 | muskegon
# Processing Record 22 of Set 4 | gidole
# Processing Record 23 of Set 4 | parintins
# Processing Record 24 of Set 4 | yulara
# Processing Record 25 of Set 4 | sinegorye
# Processing Record 26 of Set 4 | badoc
# Processing Record 27 of Set 4 | gambiran
# Processing Record 28 of Set 4 | charters towers
# Processing Record 29 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 4 | wairoa
# Processing Record 33 of Set 4 | carnarvon
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 4 | bengkulu
# Processing Record 37 of Set 4 | belyy yar
# Processing Record 38 of Set 4 | igarka
# Processing Record 39 of Set 4 | seoul
# Processing Record 40 of Set 4 | chokurdakh
# Processing Record 41 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | kapaa
# Processing Record 44 of Set 4 | yumen
# Processing Record 45 of Set 4 | alihe
# Processing Record 46 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 47 of Set 4 | bow island
# Processing Record 48 of Set 4 | ponta do sol
# Processing Record 49 of Set 4 | southern pines
# Processing Record 50 of Set 4 | ribeira grande
# Processing Record 1 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 5 | birao
# Processing Record 3 of Set 5 | mumford
# Processing Record 4 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 5 | waipawa
# Processing Record 6 of Set 5 | severo-kurilsk
# Processing Record 7 of Set 5 | klaksvik
# Processing Record 8 of Set 5 | salinopolis
# Processing Record 9 of Set 5 | boyuibe
# Processing Record 10 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 5 | boca do acre
# Processing Record 12 of Set 5 | zhigansk
# Processing Record 13 of Set 5 | nikolskoye
# Processing Record 14 of Set 5 | athabasca
# Processing Record 15 of Set 5 | naron
# Processing Record 16 of Set 5 | tuktoyaktuk
# Processing Record 17 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 5 | katherine
# Processing Record 19 of Set 5 | brae
# Processing Record 20 of Set 5 | maykain
# City not found. Skipping...
# Processing Record 21 of Set 5 | bandarbeyla
# Processing Record 22 of Set 5 | tari
# Processing Record 23 of Set 5 | viedma
# Processing Record 24 of Set 5 | lahat
# Processing Record 25 of Set 5 | ushtobe
# Processing Record 26 of Set 5 | dongning
# Processing Record 27 of Set 5 | asau
# Processing Record 28 of Set 5 | aljezur
# Processing Record 29 of Set 5 | soyo
# Processing Record 30 of Set 5 | faanui
# Processing Record 31 of Set 5 | taseyevo
# Processing Record 32 of Set 5 | lata
# Processing Record 33 of Set 5 | bredasdorp
# Processing Record 34 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 5 | victoria
# Processing Record 36 of Set 5 | mount gambier
# Processing Record 37 of Set 5 | salta
# Processing Record 38 of Set 5 | mudyuga
# City not found. Skipping...
# Processing Record 39 of Set 5 | tura
# Processing Record 40 of Set 5 | vila velha
# Processing Record 41 of Set 5 | shelabolikha
# Processing Record 42 of Set 5 | lorengau
# Processing Record 43 of Set 5 | okahandja
# Processing Record 44 of Set 5 | new norfolk
# Processing Record 45 of Set 5 | fujin
# Processing Record 46 of Set 5 | georgetown
# Processing Record 47 of Set 5 | saint-pierre
# Processing Record 48 of Set 5 | srandakan
# Processing Record 49 of Set 5 | kaitangata
# Processing Record 50 of Set 5 | cabo san lucas
# Processing Record 1 of Set 6 | port blair
# Processing Record 2 of Set 6 | faya
# Processing Record 3 of Set 6 | ayolas
# Processing Record 4 of Set 6 | sassandra
# Processing Record 5 of Set 6 | pareora
# Processing Record 6 of Set 6 | laguna de perlas
# Processing Record 7 of Set 6 | katsuura
# Processing Record 8 of Set 6 | road town
# Processing Record 9 of Set 6 | vizinga
# Processing Record 10 of Set 6 | bontang
# Processing Record 11 of Set 6 | tsiroanomandidy
# Processing Record 12 of Set 6 | harper
# Processing Record 13 of Set 6 | pisco
# Processing Record 14 of Set 6 | bilimbay
# Processing Record 15 of Set 6 | whitehorse
# Processing Record 16 of Set 6 | yanliang
# Processing Record 17 of Set 6 | brigantine
# Processing Record 18 of Set 6 | nelson bay
# Processing Record 19 of Set 6 | hasaki
# Processing Record 20 of Set 6 | angra
# City not found. Skipping...
# Processing Record 21 of Set 6 | kiunga
# Processing Record 22 of Set 6 | novosergiyevka
# Processing Record 23 of Set 6 | yaan
# Processing Record 24 of Set 6 | college
# Processing Record 25 of Set 6 | east london
# Processing Record 26 of Set 6 | sampit
# Processing Record 27 of Set 6 | souillac
# Processing Record 28 of Set 6 | ankang
# Processing Record 29 of Set 6 | santo tomas
# Processing Record 30 of Set 6 | qaqortoq
# Processing Record 31 of Set 6 | poum
# Processing Record 32 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 6 | constitucion
# Processing Record 34 of Set 6 | konstantinovka
# Processing Record 35 of Set 6 | havelock
# Processing Record 36 of Set 6 | sabla
# Processing Record 37 of Set 6 | mitu
# Processing Record 38 of Set 6 | myanaung
# Processing Record 39 of Set 6 | malinyi
# Processing Record 40 of Set 6 | nuuk
# Processing Record 41 of Set 6 | narsaq
# Processing Record 42 of Set 6 | aksarka
# Processing Record 43 of Set 6 | hithadhoo
# Processing Record 44 of Set 6 | sistranda
# Processing Record 45 of Set 6 | baghdad
# Processing Record 46 of Set 6 | falun
# Processing Record 47 of Set 6 | kruisfontein
# Processing Record 48 of Set 6 | salym
# Processing Record 49 of Set 6 | cagsiay
# Processing Record 50 of Set 6 | queanbeyan
# Processing Record 1 of Set 7 | lasa
# Processing Record 2 of Set 7 | tanout
# Processing Record 3 of Set 7 | iqaluit
# Processing Record 4 of Set 7 | dikson
# Processing Record 5 of Set 7 | sembe
# Processing Record 6 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 7 | paramonga
# Processing Record 8 of Set 7 | hobyo
# Processing Record 9 of Set 7 | landskrona
# Processing Record 10 of Set 7 | oranjemund
# Processing Record 11 of Set 7 | san-pedro
# Processing Record 12 of Set 7 | upernavik
# Processing Record 13 of Set 7 | iranshahr
# Processing Record 14 of Set 7 | kahului
# Processing Record 15 of Set 7 | vadlapudi
# Processing Record 16 of Set 7 | hokitika
# Processing Record 17 of Set 7 | boundiali
# Processing Record 18 of Set 7 | portland
# Processing Record 19 of Set 7 | norilsk
# Processing Record 20 of Set 7 | anaco
# Processing Record 21 of Set 7 | malangwa
# Processing Record 22 of Set 7 | port lincoln
# Processing Record 23 of Set 7 | pringsewu
# Processing Record 24 of Set 7 | punta gorda
# Processing Record 25 of Set 7 | kiama
# Processing Record 26 of Set 7 | mackay
# Processing Record 27 of Set 7 | vaxjo
# Processing Record 28 of Set 7 | san cristobal
# Processing Record 29 of Set 7 | lola
# Processing Record 30 of Set 7 | luanda
# Processing Record 31 of Set 7 | oktyabrskiy
# Processing Record 32 of Set 7 | poienari
# Processing Record 33 of Set 7 | methoni
# Processing Record 34 of Set 7 | mehamn
# Processing Record 35 of Set 7 | mogadishu
# Processing Record 36 of Set 7 | ostrovnoy
# Processing Record 37 of Set 7 | zhaotong
# Processing Record 38 of Set 7 | tazovskiy
# Processing Record 39 of Set 7 | burica
# City not found. Skipping...
# Processing Record 40 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 7 | fort frances
# Processing Record 42 of Set 7 | breisach
# Processing Record 43 of Set 7 | nadvoitsy
# Processing Record 44 of Set 7 | ingleside
# Processing Record 45 of Set 7 | palauig
# Processing Record 46 of Set 7 | clarence town
# Processing Record 47 of Set 7 | sovetskiy
# Processing Record 48 of Set 7 | gawler
# Processing Record 49 of Set 7 | charleston
# Processing Record 50 of Set 7 | iwanai
# Processing Record 1 of Set 8 | kavarna
# Processing Record 2 of Set 8 | nkhotakota
# Processing Record 3 of Set 8 | nouadhibou
# Processing Record 4 of Set 8 | geraldton
# Processing Record 5 of Set 8 | padang
# Processing Record 6 of Set 8 | sioux lookout
# Processing Record 7 of Set 8 | oliveira do hospital
# Processing Record 8 of Set 8 | letnyaya stavka
# Processing Record 9 of Set 8 | saint george
# Processing Record 10 of Set 8 | micheweni
# Processing Record 11 of Set 8 | chifeng
# Processing Record 12 of Set 8 | salalah
# Processing Record 13 of Set 8 | malanje
# Processing Record 14 of Set 8 | yelovo
# Processing Record 15 of Set 8 | hervey bay
# Processing Record 16 of Set 8 | duma
# Processing Record 17 of Set 8 | coquimbo
# Processing Record 18 of Set 8 | itarema
# Processing Record 19 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 8 | port hueneme
# Processing Record 21 of Set 8 | pimentel
# Processing Record 22 of Set 8 | staicele
# Processing Record 23 of Set 8 | sisimiut
# Processing Record 24 of Set 8 | ambon
# Processing Record 25 of Set 8 | kirensk
# Processing Record 26 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 8 | vostok
# Processing Record 28 of Set 8 | paharpur
# Processing Record 29 of Set 8 | lowestoft
# Processing Record 30 of Set 8 | isiolo
# Processing Record 31 of Set 8 | korla
# Processing Record 32 of Set 8 | westport
# Processing Record 33 of Set 8 | el rusio
# Processing Record 34 of Set 8 | ahuimanu
# Processing Record 35 of Set 8 | tautira
# Processing Record 36 of Set 8 | nanortalik
# Processing Record 37 of Set 8 | lleida
# Processing Record 38 of Set 8 | boyolangu
# Processing Record 39 of Set 8 | nansio
# Processing Record 40 of Set 8 | beloha
# Processing Record 41 of Set 8 | pacific grove
# Processing Record 42 of Set 8 | havre-saint-pierre
# Processing Record 43 of Set 8 | verkhoyansk
# Processing Record 44 of Set 8 | sao jose do belmonte
# Processing Record 45 of Set 8 | kudat
# Processing Record 46 of Set 8 | wenling
# Processing Record 47 of Set 8 | jiangkou
# Processing Record 48 of Set 8 | rupert
# Processing Record 49 of Set 8 | pak phanang
# Processing Record 50 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 9 | shamkhal
# Processing Record 2 of Set 9 | singkang
# Processing Record 3 of Set 9 | peleduy
# Processing Record 4 of Set 9 | mzimba
# Processing Record 5 of Set 9 | cairns
# Processing Record 6 of Set 9 | ilebo
# Processing Record 7 of Set 9 | shushtar
# Processing Record 8 of Set 9 | rabak
# Processing Record 9 of Set 9 | bay roberts
# Processing Record 10 of Set 9 | martapura
# Processing Record 11 of Set 9 | marsa matruh
# Processing Record 12 of Set 9 | ankara
# Processing Record 13 of Set 9 | santarem
# Processing Record 14 of Set 9 | xinqing
# Processing Record 15 of Set 9 | roald
# Processing Record 16 of Set 9 | muisne
# Processing Record 17 of Set 9 | khatanga
# Processing Record 18 of Set 9 | barrafranca
# Processing Record 19 of Set 9 | mayor pablo lagerenza
# Processing Record 20 of Set 9 | sakakah
# Processing Record 21 of Set 9 | ulladulla
# Processing Record 22 of Set 9 | puerto baquerizo moreno
# Processing Record 23 of Set 9 | kichera
# Processing Record 24 of Set 9 | kikwit
# Processing Record 25 of Set 9 | itacoatiara
# Processing Record 26 of Set 9 | half moon bay
# Processing Record 27 of Set 9 | berlevag
# Processing Record 28 of Set 9 | opuwo
# Processing Record 29 of Set 9 | rio gallegos
# Processing Record 30 of Set 9 | rehoboth
# Processing Record 31 of Set 9 | yacuiba
# Processing Record 32 of Set 9 | henties bay
# Processing Record 33 of Set 9 | vardo
# Processing Record 34 of Set 9 | farkhor
# Processing Record 35 of Set 9 | esperance
# Processing Record 36 of Set 9 | deputatskiy
# Processing Record 37 of Set 9 | tornio
# Processing Record 38 of Set 9 | krasnoselkup
# Processing Record 39 of Set 9 | pousat
# City not found. Skipping...
# Processing Record 40 of Set 9 | pacifica
# Processing Record 41 of Set 9 | dukat
# Processing Record 42 of Set 9 | heihe
# Processing Record 43 of Set 9 | tomatlan
# Processing Record 44 of Set 9 | araguaina
# Processing Record 45 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 46 of Set 9 | san remo
# Processing Record 47 of Set 9 | sheltozero
# Processing Record 48 of Set 9 | tasiilaq
# Processing Record 49 of Set 9 | sola
# Processing Record 50 of Set 9 | itanhaem
# Processing Record 1 of Set 10 | chilca
# Processing Record 2 of Set 10 | arlit
# Processing Record 3 of Set 10 | porto novo
# Processing Record 4 of Set 10 | kaeo
# Processing Record 5 of Set 10 | plettenberg bay
# Processing Record 6 of Set 10 | jorochito
# Processing Record 7 of Set 10 | farah
# Processing Record 8 of Set 10 | santa cruz
# Processing Record 9 of Set 10 | samarai
# Processing Record 10 of Set 10 | enshi
# Processing Record 11 of Set 10 | hamilton
# Processing Record 12 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 10 | atambua
# Processing Record 14 of Set 10 | chabahar
# Processing Record 15 of Set 10 | guarapuava
# Processing Record 16 of Set 10 | verkhnetulomskiy
# Processing Record 17 of Set 10 | batemans bay
# Processing Record 18 of Set 10 | ikwiriri
# Processing Record 19 of Set 10 | xai-xai
# Processing Record 20 of Set 10 | aklavik
# Processing Record 21 of Set 10 | mayo
# Processing Record 22 of Set 10 | canalete
# Processing Record 23 of Set 10 | pokhara
# Processing Record 24 of Set 10 | huarmey
# Processing Record 25 of Set 10 | coihaique
# Processing Record 26 of Set 10 | hofn
# Processing Record 27 of Set 10 | aguimes
# Processing Record 28 of Set 10 | christchurch
# Processing Record 29 of Set 10 | tambura
# Processing Record 30 of Set 10 | torbay
# Processing Record 31 of Set 10 | zheleznodorozhnyy
# Processing Record 32 of Set 10 | umm kaddadah
# Processing Record 33 of Set 10 | coahuayana
# Processing Record 34 of Set 10 | koster
# Processing Record 35 of Set 10 | nizhnevartovsk
# Processing Record 36 of Set 10 | erzin
# Processing Record 37 of Set 10 | kibara
# Processing Record 38 of Set 10 | baiyin
# Processing Record 39 of Set 10 | nantucket
# Processing Record 40 of Set 10 | andenes
# Processing Record 41 of Set 10 | buala
# Processing Record 42 of Set 10 | butte
# Processing Record 43 of Set 10 | centerville
# Processing Record 44 of Set 10 | sitka
# Processing Record 45 of Set 10 | seymchan
# Processing Record 46 of Set 10 | touros
# Processing Record 47 of Set 10 | kosh-agach
# Processing Record 48 of Set 10 | calama
# Processing Record 49 of Set 10 | mandalgovi
# Processing Record 50 of Set 10 | khekra
# Processing Record 1 of Set 11 | kalmunai
# Processing Record 2 of Set 11 | parit raja
# Processing Record 3 of Set 11 | lagoa
# Processing Record 4 of Set 11 | ayan
# Processing Record 5 of Set 11 | aplahoue
# Processing Record 6 of Set 11 | tyrma
# Processing Record 7 of Set 11 | honningsvag
# Processing Record 8 of Set 11 | muros
# Processing Record 9 of Set 11 | alyangula
# Processing Record 10 of Set 11 | sur
# Processing Record 11 of Set 11 | emet
# Processing Record 12 of Set 11 | chimoio
# Processing Record 13 of Set 11 | layton
# Processing Record 14 of Set 11 | neuquen
# Processing Record 15 of Set 11 | madang
# Processing Record 16 of Set 11 | saint-francois
# Processing Record 17 of Set 11 | trairi
# Processing Record 18 of Set 11 | san quintin
# Processing Record 19 of Set 11 | kimbe
# Processing Record 20 of Set 11 | maxixe
# Processing Record 21 of Set 11 | pochutla
# Processing Record 22 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 11 | scituate
# Processing Record 24 of Set 11 | ahipara
# Processing Record 25 of Set 11 | maningrida
# Processing Record 26 of Set 11 | adrar
# Processing Record 27 of Set 11 | kutum
# Processing Record 28 of Set 11 | lazaro cardenas
# Processing Record 29 of Set 11 | margate
# Processing Record 30 of Set 11 | bonthe
# Processing Record 31 of Set 11 | tilichiki
# Processing Record 32 of Set 11 | wana
# Processing Record 33 of Set 11 | nanning
# Processing Record 34 of Set 11 | kovdor
# Processing Record 35 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 11 | oil city
# Processing Record 37 of Set 11 | sadat
# Processing Record 38 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 11 | dauphin
# Processing Record 41 of Set 11 | palmer
# Processing Record 42 of Set 11 | evensk
# Processing Record 43 of Set 11 | caravelas
# Processing Record 44 of Set 11 | buenos aires
# Processing Record 45 of Set 11 | outlook
# Processing Record 46 of Set 11 | sinnamary
# Processing Record 47 of Set 11 | do gonbadan
# Processing Record 48 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 49 of Set 11 | fairbanks
# Processing Record 50 of Set 11 | bayan
# Processing Record 1 of Set 12 | auki
# Processing Record 2 of Set 12 | mapiri
# Processing Record 3 of Set 12 | port hawkesbury
# Processing Record 4 of Set 12 | basco
# Processing Record 5 of Set 12 | ulaanbaatar
# Processing Record 6 of Set 12 | bilma
# Processing Record 7 of Set 12 | san policarpo
# Processing Record 8 of Set 12 | jacareacanga
# Processing Record 9 of Set 12 | aviles
# Processing Record 10 of Set 12 | fort nelson
# Processing Record 11 of Set 12 | zhangjiakou
# Processing Record 12 of Set 12 | riohacha
# Processing Record 13 of Set 12 | barabai
# Processing Record 14 of Set 12 | acarau
# Processing Record 15 of Set 12 | tahe
# Processing Record 16 of Set 12 | karimpur
# Processing Record 17 of Set 12 | coos bay
# Processing Record 18 of Set 12 | shingu
# Processing Record 19 of Set 12 | dickinson
# Processing Record 20 of Set 12 | mana
# Processing Record 21 of Set 12 | yeppoon
# Processing Record 22 of Set 12 | el tigre
# Processing Record 23 of Set 12 | swan hill
# Processing Record 24 of Set 12 | voh
# Processing Record 25 of Set 12 | cidahu
# Processing Record 26 of Set 12 | najran
# Processing Record 27 of Set 12 | kerzhenets
# City not found. Skipping...
# Processing Record 28 of Set 12 | vryburg
# Processing Record 29 of Set 12 | iracoubo
# Processing Record 30 of Set 12 | kamskiye polyany
# Processing Record 31 of Set 12 | launceston
# Processing Record 32 of Set 12 | abonnema
# Processing Record 33 of Set 12 | willmar
# Processing Record 34 of Set 12 | kosa
# Processing Record 35 of Set 12 | quatre cocos
# Processing Record 36 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 12 | denpasar
# Processing Record 38 of Set 12 | leninskoye
# Processing Record 39 of Set 12 | avera
# Processing Record 40 of Set 12 | hualmay
# Processing Record 41 of Set 12 | kiboga
# Processing Record 42 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 43 of Set 12 | maraba
# Processing Record 44 of Set 12 | isla mujeres
# Processing Record 45 of Set 12 | bukachacha
# Processing Record 46 of Set 12 | clonakilty
# Processing Record 47 of Set 12 | sujawal
# City not found. Skipping...
# Processing Record 48 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 49 of Set 12 | klungkung
# Processing Record 50 of Set 12 | vila franca do campo
# Processing Record 1 of Set 13 | makaryev
# Processing Record 2 of Set 13 | yian
# City not found. Skipping...
# Processing Record 3 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 13 | zhanaozen
# Processing Record 5 of Set 13 | fukue
# Processing Record 6 of Set 13 | manokwari
# Processing Record 7 of Set 13 | cedeno
# Processing Record 8 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 13 | bonito
# Processing Record 10 of Set 13 | jiayuguan
# Processing Record 11 of Set 13 | senador jose porfirio
# Processing Record 12 of Set 13 | yanam
# Processing Record 13 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 13 | tabou
# Processing Record 15 of Set 13 | cape coast
# Processing Record 16 of Set 13 | winslow
# Processing Record 17 of Set 13 | okhotsk
# Processing Record 18 of Set 13 | vanavara
# Processing Record 19 of Set 13 | riyadh
# Processing Record 20 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 21 of Set 13 | xianyang
# Processing Record 22 of Set 13 | fallon
# Processing Record 23 of Set 13 | yanzhou
# Processing Record 24 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 13 | alamosa
# Processing Record 26 of Set 13 | meulaboh
# Processing Record 27 of Set 13 | novobirilyussy
# Processing Record 28 of Set 13 | la ciotat
# Processing Record 29 of Set 13 | grand gaube
# Processing Record 30 of Set 13 | zhangye
# Processing Record 31 of Set 13 | parnamirim
# Processing Record 32 of Set 13 | kota belud
# Processing Record 33 of Set 13 | cabo rojo
# Processing Record 34 of Set 13 | port macquarie
# Processing Record 35 of Set 13 | aksarayskiy
# Processing Record 36 of Set 13 | walvis bay
# Processing Record 37 of Set 13 | xingyi
# Processing Record 38 of Set 13 | madingou
# Processing Record 39 of Set 13 | ray
# Processing Record 40 of Set 13 | arcachon
# Processing Record 41 of Set 13 | vila
# Processing Record 42 of Set 13 | negara
# Processing Record 43 of Set 13 | tairua
# Processing Record 44 of Set 13 | hami
# Processing Record 45 of Set 13 | ayagoz
# Processing Record 46 of Set 13 | reforma
# Processing Record 47 of Set 13 | kargasok
# Processing Record 48 of Set 13 | ossora
# Processing Record 49 of Set 13 | altar
# Processing Record 50 of Set 13 | port hedland
# Processing Record 1 of Set 14 | port hardy
# Processing Record 2 of Set 14 | lodja
# Processing Record 3 of Set 14 | chicama
# Processing Record 4 of Set 14 | punta alta
# Processing Record 5 of Set 14 | callaguip
# Processing Record 6 of Set 14 | opunake
# Processing Record 7 of Set 14 | nyurba
# Processing Record 8 of Set 14 | petukhovo
# Processing Record 9 of Set 14 | dire dawa
# Processing Record 10 of Set 14 | batagay
# Processing Record 11 of Set 14 | abu zabad
# Processing Record 12 of Set 14 | san ignacio
# Processing Record 13 of Set 14 | pakwach
# City not found. Skipping...
# Processing Record 14 of Set 14 | saint anthony
# Processing Record 15 of Set 14 | labuan
# Processing Record 16 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 14 | makakilo city
# Processing Record 18 of Set 14 | raybag
# Processing Record 19 of Set 14 | blagoyevo
# Processing Record 20 of Set 14 | boone
# Processing Record 21 of Set 14 | berdigestyakh
# Processing Record 22 of Set 14 | almaznyy
# Processing Record 23 of Set 14 | tezu
# Processing Record 24 of Set 14 | santa maria
# Processing Record 25 of Set 14 | sai buri
# Processing Record 26 of Set 14 | fasa
# Processing Record 27 of Set 14 | khandyga
# Processing Record 28 of Set 14 | tokur
# Processing Record 29 of Set 14 | biltine
# Processing Record 30 of Set 14 | beringovskiy
# Processing Record 31 of Set 14 | vodnyy
# Processing Record 32 of Set 14 | vynohradove
# Processing Record 33 of Set 14 | frederick
# Processing Record 34 of Set 14 | kharp
# Processing Record 35 of Set 14 | novyy urengoy
# Processing Record 36 of Set 14 | baykit
# Processing Record 37 of Set 14 | gat
# Processing Record 38 of Set 14 | karatuzskoye
# Processing Record 39 of Set 14 | saint-jean-de-braye
# Processing Record 40 of Set 14 | tevaitoa
# Processing Record 41 of Set 14 | laramie
# Processing Record 42 of Set 14 | mount isa
# Processing Record 43 of Set 14 | mecca
# Processing Record 44 of Set 14 | manacor
# Processing Record 45 of Set 14 | bac lieu
# Processing Record 46 of Set 14 | awbari
# Processing Record 47 of Set 14 | adeje
# Processing Record 48 of Set 14 | zhuhai
# Processing Record 49 of Set 14 | nizhniy baskunchak
# Processing Record 50 of Set 14 | sompeta
# Processing Record 1 of Set 15 | naushki
# Processing Record 2 of Set 15 | aybak
# City not found. Skipping...
# Processing Record 3 of Set 15 | kantunilkin
# Processing Record 4 of Set 15 | craig
# Processing Record 5 of Set 15 | murgab
# Processing Record 6 of Set 15 | douentza
# Processing Record 7 of Set 15 | le port
# Processing Record 8 of Set 15 | maragogi
# Processing Record 9 of Set 15 | marawi
# Processing Record 10 of Set 15 | klyuchi
# Processing Record 11 of Set 15 | cam ranh
# Processing Record 12 of Set 15 | chongqing
# Processing Record 13 of Set 15 | raudeberg
# Processing Record 14 of Set 15 | safford
# Processing Record 15 of Set 15 | tiarei
# Processing Record 16 of Set 15 | lavrentiya
# Processing Record 17 of Set 15 | kysyl-syr
# Processing Record 18 of Set 15 | khasan
# Processing Record 19 of Set 15 | morondava
# Processing Record 20 of Set 15 | emerald
# Processing Record 21 of Set 15 | inhambane
# Processing Record 22 of Set 15 | varniai
# Processing Record 23 of Set 15 | verkhnyaya inta
# Processing Record 24 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 15 | houma
# Processing Record 26 of Set 15 | guangyuan
# Processing Record 27 of Set 15 | natitingou
# Processing Record 28 of Set 15 | katubao
# Processing Record 29 of Set 15 | booue
# Processing Record 30 of Set 15 | bosaso
# Processing Record 31 of Set 15 | guadalupe y calvo
# Processing Record 32 of Set 15 | vrsac
# Processing Record 33 of Set 15 | norden
# Processing Record 34 of Set 15 | kungurtug
# Processing Record 35 of Set 15 | vilyuysk
# Processing Record 36 of Set 15 | yazoo city
# Processing Record 37 of Set 15 | palana
# Processing Record 38 of Set 15 | carballo
# Processing Record 39 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 15 | mani
# Processing Record 41 of Set 15 | surt
# Processing Record 42 of Set 15 | kasongo-lunda
# Processing Record 43 of Set 15 | chimbote
# Processing Record 44 of Set 15 | berberati
# Processing Record 45 of Set 15 | ust-kuyga
# Processing Record 46 of Set 15 | medvedka
# Processing Record 47 of Set 15 | elesbao veloso
# Processing Record 48 of Set 15 | lubu
# Processing Record 49 of Set 15 | green river
# Processing Record 50 of Set 15 | siilinjarvi
# Processing Record 1 of Set 16 | tignapoloan
# City not found. Skipping...
# Processing Record 2 of Set 16 | tsaratanana
# Processing Record 3 of Set 16 | kamaishi
# Processing Record 4 of Set 16 | betioky
# Processing Record 5 of Set 16 | freeport
# Processing Record 6 of Set 16 | leh
# Processing Record 7 of Set 16 | gayny
# Processing Record 8 of Set 16 | uddevalla
# Processing Record 9 of Set 16 | ambilobe
# Processing Record 10 of Set 16 | bongandanga
# Processing Record 11 of Set 16 | chinsali
# Processing Record 12 of Set 16 | baturaja
# Processing Record 13 of Set 16 | miri
# Processing Record 14 of Set 16 | luoyang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 707

# %%
# Add city data to new dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cockburn Town  21.4612  -71.1419      78.8        57          40
# 1         Outram   1.2829  103.8379      77.0        88          75
# 2      Busselton -33.6500  115.3333      64.0        88          98
# 3      Kalispell  48.1958 -114.3129      44.6        49           1
# 4         Juneau  58.3019 -134.4197      37.4        87          90
#
#    Wind Speed Country Current Description
# 0       13.80      TC    scattered clouds
# 1        6.91      MY       broken clouds
# 2        1.01      AU          light rain
# 3       13.80      US           clear sky
# 4       11.50      US          light rain

# %%
# Reorder columns
new_column_order = ['City', 'Country','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Cockburn Town      TC  21.4612  -71.1419     78.80        57          40
# 1           Outram      MY   1.2829  103.8379     77.00        88          75
# 2        Busselton      AU -33.6500  115.3333     64.00        88          98
# 3        Kalispell      US  48.1958 -114.3129     44.60        49           1
# 4           Juneau      US  58.3019 -134.4197     37.40        87          90
# ..             ...     ...      ...       ...       ...       ...         ...
# 702    Bongandanga      CD   1.5000   21.0500     77.18        40           0
# 703       Chinsali      ZM -10.5414   32.0816     64.02        98         100
# 704       Baturaja      ID  -4.1333  104.1667     73.60        96         100
# 705           Miri      MY   4.4148  114.0089     77.00       100          40
# 706        Luoyang      CN  34.6836  112.4536     39.99         1           0
#
#      Wind Speed Current Description
# 0         13.80    scattered clouds
# 1          6.91       broken clouds
# 2          1.01          light rain
# 3         13.80           clear sky
# 4         11.50          light rain
# ..          ...                 ...
# 702        2.17           clear sky
# 703        1.03       moderate rain
# 704        2.24     overcast clouds
# 705        2.30    scattered clouds
# 706        2.24           clear sky
#
# [707 rows x 9 columns]

# %%
# Export dataframe
output_data_file = 'WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file, index_label='City_ID')
